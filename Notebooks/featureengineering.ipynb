# %%
DIR='/Users/ravali/Desktop/DataScience-regression/Data'
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
df = pd.read_csv(DIR+'/mlb.csv', delimiter=',',low_memory=False)

df=df.dropna()
display(df)
# Out:
#               date  season  neutral playoff team1 team2     elo1_pre  \
# 10      2018-10-08    2018        0       d   ATL   LAD  1517.892107
# 11      2018-10-08    2018        0       d   CLE   HOU  1551.097071
# 12      2018-10-07    2018        0       d   ATL   LAD  1515.467257
# 13      2018-10-07    2018        0       d   COL   MIL  1529.533596
# 14      2018-10-06    2018        0       d   BOS   NYY  1578.802911
# 15      2018-10-06    2018        0       d   HOU   CLE  1592.424849
# 16      2018-10-05    2018        0       d   LAD   ATL  1575.704646
# 17      2018-10-05    2018        0       d   BOS   NYY  1577.042515
# 18      2018-10-05    2018        0       d   MIL   COL  1548.743024
# 19      2018-10-05    2018        0       d   HOU   CLE  1589.204279
# 20      2018-10-04    2018        0       d   LAD   ATL  1572.473288
# 21      2018-10-04    2018        0       d   MIL   COL  1546.997301
# 22      2018-10-03    2018        0       c   NYY   OAK  1568.190603
# ...

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

df['month'] = pd.DatetimeIndex(df['date']).month

df['day'] = pd.DatetimeIndex(df['date']).day
df5 = df.groupby('team1').count()['playoff']
display(df5)
df5.to_csv('/Users/ravali/Desktop/DataScience-regression/Data/Featureengineering1.csv', sep=',')
# Out:
# team1
# ANA     34
# ARI     21
# ATL     86
# BAL     49
# BOS     79
# CHC     48
# CHW     25
# CIN     47
# CLE     56
# COL     10
# DET     49
# FLA     17
# HOU     40
# KCR     39
# LAD    111
# MIL     18
# MIN     42
# NYM     47
# NYY    195
# OAK     70
# PHI     55
# PIT     41
# SDP     16
# SEA     17
# SFG     84
# STL    121
# TBD     15
# TEX     25
# TOR     33
# WSN     16
# Name: playoff, dtype: int64

# %%
import numpy as np
grouped = df.groupby('team1')
df3=grouped['score1'].agg([np.sum, np.mean, np.std])
print(df3)
# Out:
#          sum      mean       std
# team1
# ANA    152.0  4.470588  2.997325
# ARI     96.0  4.571429  4.105745
# ATL    357.0  4.151163  3.273844
# BAL    194.0  3.959184  3.034243
# BOS    399.0  5.050633  3.869336
# CHC    172.0  3.583333  3.016503
# CHW     98.0  3.920000  3.402450
# CIN    174.0  3.702128  2.421955
# CLE    265.0  4.732143  3.429768
# COL     37.0  3.700000  1.702939
# DET    184.0  3.755102  2.537474
# FLA     61.0  3.588235  2.265470
# HOU    169.0  4.225000  2.759482
# KCR    166.0  4.256410  2.953303
# LAD    459.0  4.135135  2.817112
# MIL     83.0  4.611111  2.592725
# MIN    169.0  4.023810  2.664016
# NYM    201.0  4.276596  2.924426
# NYY    820.0  4.205128  2.773024
# OAK    253.0  3.614286  2.385298
# PHI    247.0  4.490909  3.005382
# PIT    143.0  3.487805  2.712213
# SDP     62.0  3.875000  2.334524
# SEA     57.0  3.352941  2.871001
# SFG    367.0  4.369048  2.823225
# STL    478.0  3.950413  2.789418
# TBD     46.0  3.066667  2.548576
# ...

# %%
df4=df3.sort_values(by='sum', ascending=False)
print(df4)
# Out:
#          sum      mean       std
# team1
# NYY    820.0  4.205128  2.773024
# STL    478.0  3.950413  2.789418
# LAD    459.0  4.135135  2.817112
# BOS    399.0  5.050633  3.869336
# SFG    367.0  4.369048  2.823225
# ATL    357.0  4.151163  3.273844
# CLE    265.0  4.732143  3.429768
# OAK    253.0  3.614286  2.385298
# PHI    247.0  4.490909  3.005382
# NYM    201.0  4.276596  2.924426
# BAL    194.0  3.959184  3.034243
# DET    184.0  3.755102  2.537474
# CIN    174.0  3.702128  2.421955
# CHC    172.0  3.583333  3.016503
# HOU    169.0  4.225000  2.759482
# MIN    169.0  4.023810  2.664016
# KCR    166.0  4.256410  2.953303
# ANA    152.0  4.470588  2.997325
# TOR    146.0  4.424242  2.500379
# PIT    143.0  3.487805  2.712213
# CHW     98.0  3.920000  3.402450
# ARI     96.0  4.571429  4.105745
# TEX     92.0  3.680000  3.400000
# MIL     83.0  4.611111  2.592725
# SDP     62.0  3.875000  2.334524
# FLA     61.0  3.588235  2.265470
# SEA     57.0  3.352941  2.871001
# ...

# %%
df4.to_csv('/Users/ravali/Desktop/DataScience-regression/Data/Featureengineering.csv', sep=',')
